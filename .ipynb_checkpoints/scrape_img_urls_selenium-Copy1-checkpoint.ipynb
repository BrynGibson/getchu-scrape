# %%
from selenium import webdriver
import pandas as pd
import lxml.html
from selenium.webdriver.chrome.options import Options 
options = Options()  
#options.add_argument("--headless")  
driver = webdriver.Chrome(r"C:\Users\sloth\Desktop\int app dev\intermediate-app-dev-concepts\05-python-5-exceptions-automation-testing\chromedriver.exe", options=options)
driver.get("http://www.getchu.com/soft.phtml?id=1077034")
age_verify_link = driver.find_element_by_link_text("[は い]")
age_verify_link.click()
#table = driver.find_element_by_xpath("//*[@id='wrapper'/table[4]")
html = driver.page_source
doc = lxml.html.fromstring(html)
imageUrl = doc.xpath('//img[contains(@alt, "キャラ")]/@src')

# %%
import lxml.html

# %%
from selenium.webdriver.chrome.options import Options

# %%
options = Options()

# %%
options.add_argument("--headless")

# %%
driver = webdriver.Chrome(r"C:\Users\sloth\Desktop\int app dev\intermediate-app-dev-concepts\05-python-5-exceptions-automation-testing\chromedriver.exe", options=options)

# %%
driver.get("http://www.getchu.com/soft.phtml?id=1077034")

# %%
driver.get("http://www.getchu.com/soft.phtml?id=4580")

# %%
age_verify_link = driver.find_element_by_link_text("[は い]")

# %%
age_verify_link.click()

# %%
table = driver.find_element_by_xpath("//*[@id='wrapper'/table[4]")

# %%
table.text
# Out:
# '朝比奈日向子\n主人公よりも一学園上の先輩。\n天然ボケで、不器用で、運動神経もない典型的なドジッ娘。\nそうしたトロい自分を自覚しているようで、まずは形から……、\nと活発な女の子に見えるように髪を短めにカットしたようだ。\n霧野きらら\n主人公のクラスメイト。\n成績優秀、スポーツ万能な優等生。\n男性に対して潔癖なところがあり、気は強いが押しに弱く、集団行動が苦手。\n自分のアニメのような名前にコンプレックスを抱いている。\n若宮千世\n主人公のクラスメイト。万葉は一卵性双生児の妹。\n明るく素直な性格で姉妹そろってクラスのマスコット的存在。\n好奇心旺盛で、どんなことにでもクビを突っ込みたがり、何かと騒がしい。\nオカルト大好き少女。\n若宮万葉\n主人公のクラスメイト。千世は一卵性双生児の姉。\n千世と性格はほぼ変わらないが、彼女の方が無邪気で幼い。\n純真であるが故か、不可思議な出来事に遭遇しやすい。\n彼女もまたオカルト大好き少女。\n花村椿\n七美学園の歴史教師にして、主人公らの担任。\nまた七美学園の卒業生でもあり、学園にまつわる不思議にも精通している。\nモデル顔負けのプロポーションと、その美貌で男子学生達に人気。'

# %%
<a href="http://www.getchu.com/soft.phtml?id=1077034&amp;gc=gc">[は い]</a>

# %%
html = driver.page_source

# %%
html
# Out:
# '<html lang="ja" xmlns:og="http://opengraphprotocol.org/schema/" xmlns:gr="http://gree.jp/ns" xmlns:mixi="http://mixi-platform.com/ns#" xmlns:fb="http://ogp.me/ns/fb#"><head>\n<title>未来はぼくらの手のなかに (シェイプシフター) (18禁) [ゲーム] - Getchu.com</title>\n<meta name="keywords" content="未来はぼくらの手のなかに ,シェイプシフター">\n<meta name="description" content="未来はぼくらの手のなかに (シェイプシフター)の商品ページです。在庫あり商品は午前中注文分は当日発送。PCゲーム/アニメ/グッズ/同人誌を買うならげっちゅ屋(Getchu.com)で。">\n<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n<meta name="twitter:card" content="summary_large_image">\n<meta name="twitter:site" content="@getchucom">\n<meta property="og:url" content="http://www.getchu.com/soft.phtml?id=4580">\n<meta property="og:title" content="未来はぼくらの手のなかに (シェイプシフター)">\n<meta property="og:description" content="未来はぼくらの手のなかに (シェイプシフター)の商品ページです。在庫あり商品は午前中注文分は当日発送。PCゲーム/アニメ/グッズ/同人誌を買うならげっちゅ屋(Getchu.com)で。">\n<meta property="og:latitude" content="35.70144">\n<meta property="og:longitude" content="139.771218">\n<meta property="og:s
# ...

# %%
doc = lxml.html.fromstring(html)

# %%
imageUrl = doc.xpath('//img[@alt="キャラ1"]/@src')

# %%
imageUrl = doc.xpath('//img[contains(@alt, "キャラ")]/@src')

# %%
imageUrl
# Out:
# ['./brandnew/1077034/c1077034chara1.jpg',
#  './brandnew/1077034/c1077034chara2.jpg',
#  './brandnew/1077034/c1077034chara3.jpg',
#  './brandnew/1077034/c1077034chara4.jpg']

# %%
driver.get_cookies()
# Out:
# [{'domain': 'www.getchu.com',
#   'expiry': 1597737597,
#   'httpOnly': False,
#   'name': 'getchu_adalt_flag',
#   'path': '/',
#   'secure': False,
#   'value': 'getchu.com'},
#  {'domain': '.getchu.com',
#   'expiry': 1597651312,
#   'httpOnly': False,
#   'name': '_gid',
#   'path': '/',
#   'secure': False,
#   'value': 'GA1.2.1106534470.1597564797'},
#  {'domain': '.getchu.com',
#   'expiry': 1597737597,
#   'httpOnly': False,
#   'name': 'ITEM_HISTORY',
#   'path': '/',
#   'secure': False,
#   'value': '1077034'},
#  {'domain': '.getchu.com',
#   'expiry': 1660636912,
#   'httpOnly': False,
#   'name': '_ga',
#   'path': '/',
#   'secure': False,
#   'value': 'GA1.2.1460049736.1597564797'}]
